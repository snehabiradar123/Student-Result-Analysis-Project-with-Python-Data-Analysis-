# %% [markdown]
# <a href="https://colab.research.google.com/github/snehabiradar123/Student-Result-Analysis-Project-with-Python-Data-Analysis-/blob/main/project1_pnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-751e9973-860c-4fdd-8b89-1ec5fb2e31d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-751e9973-860c-4fdd-8b89-1ec5fb2e31d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
F2=df.loc[(df["gender"]=="male")].count()
F=df.loc[(df["gender"]=="female")].count()
mlist=[F2["gender"],F["gender"]]

# %%
df=pd.read_csv("student-scores.csv")
df.head()
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# ...

# %%
df.describe()
# Out:
#                 id  absence_days  weekly_self_study_hours   math_score  \
# count  2000.000000   2000.000000              2000.000000  2000.000000
# mean   1000.500000      3.665500                17.755500    83.452000
# std     577.494589      2.629271                12.129604    13.224906
# min       1.000000      0.000000                 0.000000    40.000000
# 25%     500.750000      2.000000                 5.000000    77.000000
# 50%    1000.500000      3.000000                18.000000    87.000000
# 75%    1500.250000      5.000000                28.000000    93.000000
# max    2000.000000     10.000000                50.000000   100.000000
#
#        history_score  physics_score  chemistry_score  biology_score  \
# count    2000.000000    2000.000000      2000.000000     2000.00000
# mean       80.332000      81.336500        79.995000       79.58150
# std        12.736046      12.539453        12.777895       13.72219
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2000 non-null   int64
#  1   first_name                  2000 non-null   object
#  2   last_name                   2000 non-null   object
#  3   email                       2000 non-null   object
#  4   gender                      2000 non-null   object
#  5   part_time_job               2000 non-null   bool
#  6   absence_days                2000 non-null   int64
#  7   extracurricular_activities  2000 non-null   bool
#  8   weekly_self_study_hours     2000 non-null   int64
#  9   career_aspiration           2000 non-null   object
#  10  math_score                  2000 non-null   int64
#  11  history_score               2000 non-null   int64
#  12  physics_score               2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# first_name                    0
# last_name                     0
# email                         0
# gender                        0
# part_time_job                 0
# absence_days                  0
# extracurricular_activities    0
# weekly_self_study_hours       0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %% [markdown]
# **gender** **distribution**

# %%
plt.figure(figsize=(4,5))
ax= sns.countplot(data=df,x="gender")
ax.bar_label(ax.containers[0])
plt.show()

# %%
#from the above chart we have analysed that:
#the number of females in the data is more the number of males

# %%
gb= df.groupby("career_aspiration").agg({"math_score":"mean","physics_score":"mean"})
gb
# Out:
#                        math_score  physics_score
# career_aspiration
# Accountant              87.357143      81.436508
# Artist                  80.119403      80.044776
# Banker                  87.082840      79.165680
# Business Owner          69.644013      74.368932
# Construction Engineer   89.720588      90.588235
# Designer                82.357143      82.821429
# Doctor                  92.025210      91.974790
# Game Developer          89.952381      91.015873
# Government Officer      80.655738      80.377049
# Lawyer                  86.036232      80.275362
# Real Estate Developer   76.421687      81.734940
# Scientist               87.666667      91.897436
# Software Engineer       92.146032      81.149206
# Stock Investor          88.109589      80.013699
# Teacher                 78.593220      79.966102
# Unknown                 79.843049      80.946188
# Writer                  78.312500      84.125000

# %% [markdown]
# **change career aspiration column**

# %%
df["career_aspiration"]=df["career_aspiration"].str.replace("Unknown","Artist")
df.head()
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# ...

# %%
sns.heatmap(gb,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gb1= df.groupby("weekly_self_study_hours").agg({"math_score":"mean","physics_score":"mean"})
gb1.head(8)
# Out:
#                          math_score  physics_score
# weekly_self_study_hours
# 0                         75.028571      75.885714
# 1                         75.426966      78.606742
# 2                         76.314607      78.651685
# 3                         73.754902      79.000000
# 4                         75.833333      77.843137
# 5                         72.659574      80.468085
# 6                         79.086957      80.782609
# 7                         81.272727      84.272727

# %%
sns.boxplot(data=df,x="math_score")
plt.show()

# %%
sns.boxplot(data=df,x="physics_score")
plt.show()

# %%
print(df["extracurricular_activities"].unique())
# Out:
# [False  True]

# %% [markdown]
# **Distribution of** ***extracurricular_activities***

# %%
F=df.loc[(df["extracurricular_activities"]=="False")].count()
F
# Out:
# id                            0
# first_name                    0
# last_name                     0
# email                         0
# gender                        0
# part_time_job                 0
# absence_days                  0
# extracurricular_activities    0
# weekly_self_study_hours       0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %% [markdown]
# **Distribution of** **gender**

# %%
F=df.loc[(df["gender"]=="female")].count
print(F)
# Out:
# <bound method DataFrame.count of         id first_name last_name                                    email  \
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 5        6      Kelly      Wade           kelly.wade.6@gslingacademy.com
# 9       10     Audrey   Simpson      audrey.simpson.10@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1987  1988      Holly  Erickson    holly.erickson.1988@gslingacademy.com
# 1991  1992  Charlotte      Rowe    charlotte.rowe.1992@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
F2=df.loc[(df["gender"]=="male")].count
print(F2)
# Out:
# <bound method DataFrame.count of         id first_name  last_name                                  email  \
# 0        1       Paul      Casey         paul.casey.1@gslingacademy.com
# 4        5    Anthony     Campos     anthony.campos.5@gslingacademy.com
# 6        7    Anthony      Smith      anthony.smith.7@gslingacademy.com
# 7        8     George      Short       george.short.8@gslingacademy.com
# 8        9    Stanley  Gutierrez  stanley.gutierrez.9@gslingacademy.com
# ...    ...        ...        ...                                    ...
# 1992  1993       John   Peterson   john.peterson.1993@gslingacademy.com
# 1993  1994      Shawn      Ochoa     shawn.ochoa.1994@gslingacademy.com
# 1994  1995     Steven      Lewis    steven.lewis.1995@gslingacademy.com
# 1995  1996       Alan   Reynolds   alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas    Gilbert  thomas.gilbert.1997@gslingacademy.com
#
#      gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
M=df.loc[(df["gender"]=="male")].count()
F=df.loc[(df["gender"]=="female")].count()
mlist=[F["gender"],M["gender"]]
l=["M","F"]
plt.pie(mlist,labels=l,autopct="%1.2f%%")
plt.title("Distribution of gender")
plt.show()
